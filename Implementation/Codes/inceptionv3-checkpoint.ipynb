# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
import tensorflow as tf
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import SGD
from tensorflow import keras

# %%
pip install split-folders
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import splitfolders
input_folder = r"C:\Users\Young\Desktop\DeepLearning\Nonsegmented"

# %%
splitfolders.ratio(input_folder, output="test_1", 
                   seed=42, ratio=(.8, .2), 
                   group_prefix=None)
# Out:
# Copying files: 5544 files [00:46, 120.30 files/s]

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1/255,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1/255 ,
                                 shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

# %%
train_set = train_datagen.flow_from_directory(r"C:\Users\Young\Desktop\DeepLearning\test_1\train" ,
                                                target_size = (150,150) ,
                                                batch_size = 128 ,
                                                class_mode = 'categorical')
# Out:
# Found 4430 images belonging to 12 classes.

# %%
test_set = test_datagen.flow_from_directory(r"C:\Users\Young\Desktop\DeepLearning\test_1\val" ,
                                                target_size = (150,150) ,
                                                batch_size = 128,
                                                class_mode = 'categorical')
# Out:
# Found 1114 images belonging to 12 classes.

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
base_model = InceptionV3(input_shape = (150, 150, 3), include_top = False, weights = 'imagenet')

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras import layers

x = layers.Flatten()(base_model.output)
x = layers.Dense(1024, activation='relu')(x)
x = layers.Dropout(0.2)(x)

# Add a final ReLu layer with 1 node for classification output
x = layers.Dense(1, activation='relu')(x)

model = tf.keras.models.Model(base_model.input, x)

model.compile(optimizer = RMSprop(learning_rate=0.001), loss = 'mae', metrics = ['acc'])

# %%
inc_history = model.fit(train_set, validation_data = test_set, steps_per_epoch = 30, epochs = 10)
# Out:
# Epoch 1/10
# 30/30 [==============================] - 144s 5s/step - loss: 0.0833 - acc: 0.9167 - val_loss: 0.0833 - val_acc: 0.9167
# Epoch 2/10
# 30/30 [==============================] - 139s 5s/step - loss: 0.0833 - acc: 0.9167 - val_loss: 0.0833 - val_acc: 0.9167
# Epoch 3/10
# 30/30 [==============================] - 131s 4s/step - loss: 0.0833 - acc: 0.9167 - val_loss: 0.0833 - val_acc: 0.9167
# Epoch 4/10
# 30/30 [==============================] - 146s 5s/step - loss: 0.0833 - acc: 0.9167 - val_loss: 0.0833 - val_acc: 0.9167
# Epoch 5/10
# 30/30 [==============================] - 164s 6s/step - loss: 0.0833 - acc: 0.9167 - val_loss: 0.0833 - val_acc: 0.9167
# Epoch 6/10
# 30/30 [==============================] - 171s 6s/step - loss: 0.0833 - acc: 0.9167 - val_loss: 0.0833 - val_acc: 0.9167
# Epoch 7/10
# 30/30 [==============================] - 153s 5s/step - loss: 0.0833 - acc: 0.9167 - val_loss: 0.0833 - val_acc: 0.9167
# Epoch 8/10
# ...

# %%
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 150, 150, 3  0           []
#                                 )]
#
#  conv2d_94 (Conv2D)             (None, 74, 74, 32)   864         ['input_2[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 74, 74, 32)  96          ['conv2d_94[0][0]']
#  ormalization)
#
#  activation_94 (Activation)     (None, 74, 74, 32)   0           ['batch_normalization_94[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 72, 72, 32)   9216        ['activation_94[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 72, 72, 32)  96          ['conv2d_95[0][0]']
#  ormalization)
#
#  activation_95 (Activation)     (None, 72, 72, 32)   0           ['batch_normalization_95[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 72, 72, 64)   18432       ['activation_95[0][0]']
#
# ...
